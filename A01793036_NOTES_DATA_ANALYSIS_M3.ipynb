# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Julian_Gongora_A01793036/blob/main/A01793036_NOTES_DATA_ANALYSIS_M3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julian David Gongora Forero - Matrícula: A01793036 - Correo: A01793036@tec.mx**
#
# **Notas del curso Data Analysis with Python Course  Modulo:_3*

# %% [markdown]
# >>  **MODULE 3: EXPLORATORY DATA ANALYSIS**
#
#
#
#
# Exploratory Data Analysis, or in short “EDA”, is an approach to analyze data in order to:
# - summarize main characteristics of the data - gain better understanding of the dataset,
# - uncover relationships between different variables, and
# - extract important variables for the problem we are trying to solve.
# In this module you will learn about: Descriptive Statistics, which describe basic features of a dataset and obtains a short summary about the sample and measures of the  data. Basic of Grouping Data using group by, and how this can help to transform our dataset. ANOVA, the analysis of variance, a statistical method in which the variation in a set of observations is divided into distinct components.
#
# **1.	Descriptive Statistics:**
# Descriptive statistical analysis helps to describe basic features of a dataset and obtains a short summary about the sample and measures of the data. Let’s show you a couple different useful.
#
# 1.1.	df.describe()  #to show several descriptive Statistics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.2.	 value_counts() #to count the number of categorical values.
# New_df=df(“elemnt_to-count”).value_counts()
#
# 1.3.	You can ser graphic tools like
# -Box plots.
# sns.boxplot(x = ”column_X”, y = ”column_Y” , data=df)
# -Scatterplot: grafica de puntos entre dos variables.
#
# y = df[“engine-size”]
#
# x = df[“price”]
#
# plt.scatter(x,y)
#
# plt.title(“nombre_grafica”)
#
# plt.xlabel(“nombre eje x”)
#
# plt.ylabel(nombre eje y)
#
# **2.	GroupBy in Python:** Assume you want to know: Is there any relationship between the different types of categorical variables.
# The group by method is used on categorical variables, groups the data into subsets according to the different categories of that variable.
#
# The group by method is used on categorical variables, groups the data into subsets according to the different categories of that variable.
#
# The pivot method: A pivot table has one variable displayed along the columns and the other variable displayed along the rows.
#
# df_pivot = df_grp.pivot(index= “ColumX”, columns=”ColumY”)
#
# Other methot is the Heat map plot : add a color depends on the value of the thirth

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3.	 Analysis of Variance ANOVA:** Assume that we want to analyze a categorical variable and see the correlation among different categories. ANOVA can be used to find the correlation between different groups of a categorical variable.
# -The F-test calculates the ratio of variation between the groups's mean over the variation within each of the sample groups.
# - The p-value shows whether the obtained result is statistically significant.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **4.	Correlation:** Correlation is a statistical metric for measuring to what extent different variables are interdependent. In other words, when we look at two variables over time, if one variable changes, how does this effect change in the other variable?
# Sns.regplot(x=”variable_x”, y= “variable_y”, data=df)
# plt.ylim(0,)
# Correltion could be negative o positive, depends on the pendiente of the linear line. If the line is almost plane, the correlation is poor or does not exist.
#
# **5.	Correlation – Statistics:**  The Pearson correlation method, will give you two values, the Correlation coefficient and the p-value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pearson_coef, p_value = stats.pearsonr(df([“variable_x”], df[“variable_y”])
#
# Perason Correlation: W
#
# P-value: Z

# %% [markdown]
# **REASULST**
#
# ![image.png](data:image/png;base64,...)
