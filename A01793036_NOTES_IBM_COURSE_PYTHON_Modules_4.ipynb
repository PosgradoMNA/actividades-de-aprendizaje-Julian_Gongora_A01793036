# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Julian_Gongora_A01793036/blob/main/A01793036_NOTES_IBM_COURSE_PYTHON_Modules_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julian David Gongora Forero** **- Matrícula: A01793036** **- Correo: A01793036@tec.mx**
#
# **NOTAS DEL CURSO DEL  CURSO PYTHON FOR DATA SCIENCE MÓDULO 4**
#
# **LEARNING OBJETIVES**
# - Reading files with open
# - Writing files with open
# - Loading data with Pandas
# - Working with and Saving data with Pandas
#
# **NOTES** - Para leer files:  In this section we will use Python’s built-in open function to create a file object.
# - Usar la funcion open para abrir el archivo, donde hay directorio, nombre del archivo yagregar  modo.
# - Modos: R para Reading, w para wrinting & para appending
# - Por último el file objet.
# - File.name para el nombre
# - File.mode para el modo
# - File.close() para cerrar el file como opuesto de close
# - Utilizar el “with open” para utilizar el file y cerrarlo automáticamente
# with open (2example1.txt”,”r”) as file1:
# - File_stuff=File1.readlines(16)
# - Print(file_stuff)    #Imprime los primeros 16 catacteres del file, del 0 al 15.
# - File_stuff=File1.readlines(5)
# - Print(file_stuff)    #Imprime los siguientes 5 caractéres del file, del 16 al 20 y así...
# - head() La función Python Pandas Series. head() devuelve una serie de valores seleccionados desde el principio
# - Para escribir file con open
# - We can also write to files using the open function.
# ![IBM m4 V3.png](data:image/png;base64,...)![IBM m4 V2.png](data:image/png;base64,...)![IBM m4 V1.png](data:image/png;base64,...)
#
#
# **Loading Data with Pandas:**
# - Pandas es una libreria para análisis de datos ” import pandas “  para  utilizar funciones y prebuild clases.  Función es pandas.funcion
# - Eje: pandas.read csv (ubicación) para cargar un archivo
# - pandas = pd
# - dataframe=df
# - Ubicación de elementos:   df.ix (x:y)
# - Ubicar de tablas:  Z = df.ix (x:y,z:w) Z será un nueva tabla.
#
# **Working with and Saving Data with Panda**
# - df(“column”).unique() = para mostrar los valores únicos en una columna
# - Se puede incluir condicionales para seleccinar varios rows de la base de datos.
# - D1=df(df(“released”) >=1980) para seleccinar filas con año superior a 1980
# - No olvides guardar la el archivo en un formato por ejemplo .csv
#
# ![IBM m4.PNG](data:image/png;base64,...)
