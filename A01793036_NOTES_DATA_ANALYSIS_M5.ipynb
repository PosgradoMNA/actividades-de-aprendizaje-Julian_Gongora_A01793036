# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Julian_Gongora_A01793036/blob/main/A01793036_NOTES_DATA_ANALYSIS_M5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julian David Gongora Forero - Matrícula: A01793036 - Correo: A01793036@tec.mx**
#
# **Notas del curso Data Analysis with Python Course  Modulo:_5*

# %% [markdown]
# #**MODULE 5- MODEL EVALUATION**
# **GOAL:** Model Evaluation and Refinement: In this lesson you will learn about: Model Evaluation Over-fitting, Under-fitting and Model Selection Ridge Regression Grid Search And answer the Question: How can you be certain your model works in the real world and performs optimally.
# 1.	**Model Evaluation:** Model Evaluation tells us how our model preforms in the real world.
# In-sample evaluation tells us how well our model fits the data already given to train It. It does not give us an estimate of how well the trained model can predict new data.
# The solution is to split our data up, use the In-sample data or training data to train the model. The rest of the data called test data is used as out-of-sample data.
# This data is then used to approximate how the model performs in the real world.
# FUNCTION train_test_split() to split the data: from sklearn.model_salection import train_test_split
# Generalization error is a measure of how well our data does at predicting previously unseen data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **IMPORTANT:** Using a lot of data for training gives us an accurate means of determining how our model will perform in the real world, but the precision of the performance will be low. To overcome this problem, we use cross validation.
#
# **2.CROSSVALIDATION:** One of the most common out-of-sample evaluation metrics is cross-validation.
# 1st: In this method, the dataset is split into k-equal groups; each group is referred to as a fold.
# 2nd: Some of the folds can be used as a training set, which we use to train the model, and the remaining parts are used as a test set, which we use to test the model.
# 3rd: This is repeated until each partition is used for both training and testing. At the end, we use the average results as the estimate of out-of-sample error.
#
# FUNCTION cross_val_score(): perform multiple 'out-of-sample' evaluations.

# %% [markdown]
# From sklearn.model_selection import cross_val_predict
#
# scores= cross_val_score(lr,x_data, y_data, cv=3)
#
# Lr is for linear regression
#
# CV = numero de particiones.
#
# **3. Overfitting, Underfitting and Model Selection:**
# In this section, we will discuss how to pick the best polynomial order and problems that arise with selecting the wrong order polynomial.
# Undefirring: the model does not fit enough the data. (order to low)
# Overfitting: the model  model is too flexible and fits the noise rather than the function.
# The plot of the mean square error for the training and testing set for different order polynomials.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# IMPORTANTE: Take in account the irreducible error will still exist, always.
#
# **4.	Ridge Regression:** Ridge regression prevents over-fitting. we will focus on polynomial regression for visualization, but over-fitting is also a big problem when you have multiple independent variables or features. The estimated function in blue does a good job at approximating the true function.  In many cases real data has outliers.
# Ridge regression controls the magnitude of these polynomial coefficients by introducing the parameter alpha. From 0 to 10.
#
# FORMULA:
#
# From sklearn.linear_model import Ridge
#
# RigeModel= Ridge(alpha= 0.1)
#
# RigeModel.fit(X,y)
#
# Yhat=RigeModel.predict(X)
#
# Try with different values from 0 to 10, and select the one with the highest value.
#
# **5.Grid Search:** Grid search allows us to scan through multiple free parameters with few lines of code. These values are called hyperparameters.
# Grid search takes the model or objects you would like to train and different values of
# The hyperparameters. It then calculates the mean square error or R squared for various hyperparameter values,  allowing you to choose the best values.
# To select the hyperparameter, we split our dataset into three parts, the training set, validation set, and test set.
#
# FORMULA:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**PROGRESO Y RESULTADOS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
