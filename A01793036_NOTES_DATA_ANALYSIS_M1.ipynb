# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Julian_Gongora_A01793036/blob/main/A01793036_NOTES_DATA_ANALYSIS_M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julian David Gongora Forero - Matrícula: A01793036 - Correo: A01793036@tec.mx**
#
# **Notas del curso Data Analysis with Python Course  Modulo:_1**

# %% [markdown]
# **1 The problem:** the importance of data analysis. As you know, data is collected everywhere around us, whether it's collected manually. So data analysis plays an important role by helping us to discover useful information from the data, answer questions, and even predict the future or the unknown. Real problems the life.  As a data analyst or data scientist, these are some of the questions we can start thinking about. To answer these questions, we're going to need some data.
#
# **2 Understanding the Data:** Check out all variables, columns and simple understand what information you have at hand to lands scape the situation. Ok, after we understand the meaning of each feature, we'll notice that the 26th attribute is "price". This is our target value, or label, in other words. This means "price" is the value that we want to predict from the dataset, and the predictors should be all the other variables listed, like "symboling", "normalized-losses".
#
# **3 Python Packages for Data Science:** In order to do data analysis in Python, we should first tell you a little bit about the main packages relevant to analysis in Python. A Python library is a collection of functions and main packages relevant to analysis in Python. A Python library is a collection of functions and methods that allow you to perform lots of actions without writing any code. The libraries usually contain built-in modules providing different functionalities, which you can use directly.

# %% [markdown]
# **4 Scientific computing libraries:**
#
# **4.1 Pandas:**  offers data structure and tools for effective data manipulation and analysis. It provides fast access to structured data. The primary instrument of Pandas is a two-dimensional table consisting of column and row labels (Data Fram).
#
# **4.2 Numpy:** library uses arrays for its inputs and outputs. It can be extended to objects for matrices, and with minor coding changes, developers can perform fast array processing.
#
# **4.3 SciPy** includes functions for some advanced math problems, as listed on this slide, as well as data visualization.
#
# **5. Data visualization** methods is the best way to communicate with others, showing them meaningful results of analysis. These libraries enable you to create graphs, charts and maps.
# - 5.1 The **Matplotlib** package is the most well-known library for data visualization. It is great for making graphs and plots.
# - **5.2 Seaborn:** It's very easy to generate various plots such as heat maps, time series, and violin plots. With Machine Learning algorithms, we're able to develop a model using our dataset.
#
# 6. **The algorithmic libraries** tackle some machine learning tasks from basic to complex. The Scikit-learn library & StatsModels

# %% [markdown]
# **7. Importing and Exporting Data in Python:** Data acquisition of the data. Important to review Format is the way data is encoded.
#
# **7.1 Format** is the way data is encoded. We can usually tell different encoding schemes by looking at the ending of the file name. Some common encodings are csv, json, xlsx, hdf and so forth. Como viene, el formato.
#
# **7.2 The (file) path** tells us where the data is stored. Usually it is stored either on the computer we are using, or online on the internet. Donde esta.
#
# **7.3 Read info whit Pandas:**  In pandas, the “read_csv()” method can read in files with columns separated by commas.
#
# Import pandas as pd
# - Then define a variable with the file path.
# url = “www…”
# - And then use the read_csv method to import the data.
# df = pd.read_csv(url)
# - print de data set to take a look
# df print
# df.head (n)   #muestra las primeras n filas
# fd.tail
#
# 7.4 **To save:**  At some point in time after you’ve done operations on your dataframe, you may want to export your pandas dataframe to a new CSV file.
# df.to_csv(path)

# %% [markdown]
# 8. Getting Started Analyzing Data in Python: Pandas has several built in methods that could be used to understand the datatype of features or to look at the distribution of data within the dataset.
#
# 8.1 Check de data types on pandas similar to pyton.
#
# **df.dtypes**  #to chek de data types
#
# **df.describe ()** #arroja una serie de información estadística para revisar el caso.
#
# **df.info()** #arroja los datos de los primers 30 columnas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
