# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Julian_Gongora_A01793036/blob/main/A01793036_NOTES_IBM_COURSE_PYTHON_Modules_1_%26_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julian David Gongora Forero** **- Matrícula: A01793036** **- Correo: A01793036@tec.mx**
#
# **NOTAS DEL CURSO DEL  CURSO PYTHON FOR DATA SCIENCE MÓDULOS 1,2 Y 3**
#
# Learning Objectives
# *	Definición de: What is Python and why it is useful
# *	Aplicaciones of Python
# *	Como  definir las variables
# *	Sets and conditional statements in Python
# *	The purpose of having functions in Python
# *	How to operate on files to read and write data in Python
# *	How to use pandas, a must-have package for anyone attempting data analysis in Python
#
# Modulo 1 - Python Basics
# *	Your first program
# *	Types
# *	Expressions and Variables
# *	String Operations
#
# Module 2 - Python Data Structures
# *	Lists and Tuples
# *	Sets
# *	Dictionaries
# Module 3 - Python Programming Fundamentals
# *	Conditions and Branching
# *	Loops
# *	Functions
# *	Objects and Classe
#
# **NOTES Module 1 - Python Basics**
#
# - Python. A statement or expression is an instruction
# - Comandos: Print statement (argument) Print(“hello word es Julian)
# - Comentarios: # it is just a comment and is not taken in account. # Print(“hello word es Julian)
# - Nota: It could be a syntax error or semantic error.
# - Tipos de vriablaes: is how data is represented.
# - Integers (1,2,3…), floats (1.0, 1.6…), strings(1,2,3), Boolean (tru/false).
# - Expressions describe a type of operation that computers perform (operations).
# -Variables: assign a numeric value to a variable: X=1+2 or Y=X*8
# - A string is a sequence of characters.  “Michaell Jackson”
# - Using an index represented by the array of numbers.
# - The method replaces a segment of the string, i.e., a substring with a new string. Example: upper.
#
#
# **NOTES: Module 2 Python Data Structures**
#
# *   Concepto principal son las Lists and tuples compound data types and are. Tuple1 = ("disco",1,2.3)
# - Tuples are an ordered sequence in parentheses. Ex: Rating=(1,8,15,disco)
# - Recordar que inicia 0 desde la iz pero negativo desde derecha inicia negativo. Each element of a tuple can be accessed via an index. Tuple1[0]=1
# - It is possible to concatenate or combine tuples by adding them.
# - Importante: Tuples are immutable.
# - Pero: Lists are also an ordered sequence in square brackets and are mutable.
# - Pero: Lists can contain strings, floats, integers. Listas L=[a,s,d,y]
# - Sets (conjuntos) are a type of collection. This means that like lists and tuples, you can input different python types. Unlike lists and tuples, they are unordered.
# - Can input different python types. Unlike lists and tuples, they are unordered. This means sets do not record element position. Sets only have unique elements.
# - To define a set, you use curly brackets You place the elements of a set within the curly brackets. You notice there are duplicate items.
# - You can convert a list to a set by using the function set; this is called type-casting.
# - EJEMPLO:  Set1={"rock","disco","1"}
# - We just put the set name followed by a dot then the remove method.
# - Es la misma teoria de CONJUNTOS. There are lots of useful mathematical operations we can do between sets. Operaciones entre conjuntos.
# -Unión, intersection, lo que está en solo uno, o mutuamente exclusivo. Contenido, sub conjunto etc.
# - Funcionan para hacer tablas para el procesamiento de información. DICT["BAT OUT OF HELL"] Dictionaries are a type of collection in Python. The key is analogous to the index, they are like addresses but they don’t have to be integers. They are usually characters; the values are similar to the elements in a list and contain information.
# -Used for dictionaries is helpful to use the table to visualize data.
# - we can use the method keys to get the keys. The output is a list like object with all the keys. In the same way, we can obtain the values using the method values.
#
#
#
# **NOTES: Module 3  - Python Programming Fundamentals**
#
# - Este leccion se trata sobre condiciones and branching
# - La comparacion arroja un Booleano: igual, menor, mayor.
# - If i=6, i>3, True. Funciona con cualqueri tipo de variable Ej. Strings.
# - Se puede combiner una condicion para arrojar un string
#   Ej: If(age>18):
#   print(“you can enter”)
#   Else
#   print(“move on”)
# - elseif: un Segundo if para hacer logic operations.
# - El condicional OR se puede agregar para evaluar dos o más condiciones.
# - El condcional AND se puede agregar para evaluar dos o más condiciones.
# - Vamos a ver dos tipos de Loops
# - Rango(N:Z) = nuermos de de N a X
# - for I in range (0,5):  program lo que hace…. Esto cambia la “I” en un rango de 0 a 5.
# - While Loops: only run when the conditions is meet. Ejecuta el commando hasta que la condicion se cumple.
# - Funciones: como usarlas y usar propias funciones. Son un pedazo de code que se puede reutilizar. Tiene un input y un output, para hacer el codigo más corto y efeciente.
# - Por ejemplo: leng, sum, sort, etc…
# - Tener cuidado si se altera la lista, o si se crea una nueva lista. Sorted Vs Sort.
# - Funcion def add(A) para reemplazar en una fucion variables.
# - Mult(a,b)=a*b  take in account int will double strings.
# - Loops can be use in functions
# - Objet: Type, internal data, methods
# - Los methods como interactuar con los datos.
# - Clases define caracteristicas que define el objeto.
# - Ej: Class Circle(objet):
# - Es possible contruir con diferentes objetos con clases.
#
# ![IBM 12&3.PNG](data:image/png;base64,...)
